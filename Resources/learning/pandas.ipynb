# %%
! pip install pandas numpy matplotlib

# %%
import pandas as pd

# %%
df = pd.read_csv('call_activity.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
type(df['State'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Build DataFrames From Dictionaries

# %%
student_data = {
    "names": ["Aarav", "Diya", "Kabir", "Meera"],
    "subjects": ["Math", "Science", "English", "History"],
    "marks": [88, 92, 75, 81],
    "grades": ["A", "A+", "B", "A"]
}

# %%
pdDict = pd.DataFrame.from_dict(student_data)
pdDict
# Out:
#    names subjects  marks grades
# 0  Aarav     Math     88      A
# 1   Diya  Science     92     A+
# 2  Kabir  English     75      B
# 3  Meera  History     81      A

# %%
pdDict.head()
# Out:
#    names subjects  marks grades
# 0  Aarav     Math     88      A
# 1   Diya  Science     92     A+
# 2  Kabir  English     75      B
# 3  Meera  History     81      A

# %% [markdown]
# # back to call_activity data

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
df.iloc[12]
# Out:
# State                        IA
# Account length              168
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         104.9
# Total eve calls            71.0
# Total eve charge           8.92
# Total night minutes       141.1
# Total night calls         128.0
# Total night charge         6.35
# Total intl minutes         11.2
# Total intl calls              2
# Total intl charge          3.02
# Customer service calls      1.0
# Churn                     False
# Name: 12, dtype: object

# %%
df.iloc[12,3] # row ,column
# Out:
# 'No'

# %%
df.iloc[-1] # last row
# Out:
# State                        TN
# Account length               74
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         234.4
# Total day calls           113.0
# Total day charge          39.85
# Total eve minutes         265.9
# Total eve calls            82.0
# Total eve charge           22.6
# Total night minutes       241.4
# Total night calls          77.0
# Total night charge        10.86
# Total intl minutes         13.7
# Total intl calls              4
# Total intl charge           3.7
# Customer service calls      0.0
# Churn                     False
# Name: 3332, dtype: object

# %%
# slicing
df.iloc[10:21]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 10    IN              65        415                 No              No
# 11    RI              74        415                 No              No
# 12    IA             168        408                 No              No
# 13    MT              95        510                 No              No
# 14    IA              62        415                 No              No
# 15    NY             161        415                 No              No
# 16    ID              85        408                 No             Yes
# 17    VT              93        510                 No              No
# 18    VA              76        510                 No             Yes
# 19    TX              73        415                 No              No
# 20    FL             147        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# loc method - keywords instead of indexes

state = df.copy()

# %%
state.set_index('State', inplace = True)  # look entire data has be brought with respect to state , index column got replaced

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
# now apply loc funciton 
state.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# ...

# %%
# reset back the index
state.reset_index()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# check for nulls

df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.shape
# Out:
# (3307, 20)
